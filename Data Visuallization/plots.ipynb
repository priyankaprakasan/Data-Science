# %%
import matplotlib.pyplot as plt
#%matplotlib inline
# %matplotlib notebook

# %%
plt.plot(5,5,'o')
#plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 0, 'X')

# %%
plt.xlabel("X")
plt.ylabel("Y")
# Out:
# Text(40.052083333333336, 0.5, 'Y')
